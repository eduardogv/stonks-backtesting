# %% [markdown]
# # Recolección de Datos

# %%
# importamos librerias

import pandas as pd
import yfinance as yf
from finta import TA

# %%
# importamos la data desde internet

tickers = pd.read_csv("https://pkgstore.datahub.io/core/nyse-other-listings/nyse-listed_csv/data/3c88fab8ec158c3cd55145243fe5fcdf/nyse-listed_csv.csv")

# %%
tickers
# Out:
#      ACT Symbol                                       Company Name
# 0             A            Agilent Technologies, Inc. Common Stock
# 1            AA                            Alcoa Inc. Common Stock
# 2          AA$B  Alcoa Inc. Depository Shares Representing 1/10...
# 3           AAC                    AAC Holdings, Inc. Common Stock
# 4           AAN                         Aaron's, Inc. Common Stock
# ...         ...                                                ...
# 3293       ZPIN  Zhaopin Limited American Depositary Shares, ea...
# 3294        ZQK                      Quiksilver, Inc. Common Stock
# 3295        ZTR   Zweig Total Return Fund, Inc. (The) Common Stock
# 3296        ZTS                   Zoetis Inc. Class A Common Stock
# 3297         ZX  China Zenix Auto International Limited America...
#
# [3298 rows x 2 columns]

# %%
# Creamos una LISTA solo de los simbolos, que es lo que nos interesa
symbols = tickers["ACT Symbol"].unique()

# %%
symbols
# Out:
# array(['A', 'AA', 'AA$B', ..., 'ZTR', 'ZTS', 'ZX'], dtype=object)

# %%
# DEscargamos data como en el anterior tutorial
df = yf.download(symbols[0], auto_adjust=True, period='5y')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Cambiamos a minusuclas 
df.columns = df.columns.str.lower()

# Renombramos el indice
df.index = df.index.rename("datetime")

# %%
df
# Out:
#                   open        high         low       close   volume
# datetime
# 2018-04-23   65.240311   66.165295   65.066876   65.587181  2260600
# 2018-04-24   63.968454   65.433017   63.631222   64.209335  3701600
# 2018-04-25   64.257508   64.633282   62.542434   63.399971  4451600
# 2018-04-26   63.804650   64.324955   63.496323   63.949181  1978600
# 2018-04-27   63.920289   64.132266   63.554152   63.862480  1189200
# ...                ...         ...         ...         ...      ...
# 2023-04-17  139.619995  140.210007  138.889999  140.190002  1115500
# 2023-04-18  140.729996  140.990005  138.210007  139.000000  1218900
# 2023-04-19  138.369995  139.619995  137.679993  138.929993  1178400
# 2023-04-20  136.860001  137.050003  134.869995  135.529999  1325900
# 2023-04-21  136.210007  138.559998  136.210007  138.500000  1533600
#
# [1259 rows x 5 columns]

# %% [markdown]
# Guardamos la data como csv en la carpeta price_data

# %%
df.to_csv(f"price_data/{symbols[0]}.csv")

# %%
# Recargamos el csv y definimos nuevamente el indice porque no se guardó

loaded_csv = pd.read_csv(f"price_data/{symbols[0]}.csv", index_col="datetime")

# %%
loaded_csv
# Out:
#                   open        high         low       close   volume
# datetime
# 2018-04-23   65.240311   66.165295   65.066876   65.587181  2260600
# 2018-04-24   63.968454   65.433017   63.631222   64.209335  3701600
# 2018-04-25   64.257508   64.633282   62.542434   63.399971  4451600
# 2018-04-26   63.804650   64.324955   63.496323   63.949181  1978600
# 2018-04-27   63.920289   64.132266   63.554152   63.862480  1189200
# ...                ...         ...         ...         ...      ...
# 2023-04-17  139.619995  140.210007  138.889999  140.190002  1115500
# 2023-04-18  140.729996  140.990005  138.210007  139.000000  1218900
# 2023-04-19  138.369995  139.619995  137.679993  138.929993  1178400
# 2023-04-20  136.860001  137.050003  134.869995  135.529999  1325900
# 2023-04-21  136.210007  138.559998  136.210007  138.500000  1533600
#
# [1259 rows x 5 columns]

# %% [markdown]
# ### Ahora cramos una función para descargar masivamente todo

# %%
def download_stock_data(folder="price_data", years=5):
    tickers = pd.read_csv("https://pkgstore.datahub.io/core/nyse-other-listings/nyse-listed_csv/data/3c88fab8ec158c3cd55145243fe5fcdf/nyse-listed_csv.csv")
    symbols = tickers["ACT Symbol"].unique()
    print (symbols)
    for symbol in symbols:
        print (symbol)
        print (f"Guardando info en: {folder}/{symbol}.csv")
        try:
            df = yf.download(symbol, auto_adjust=True, period=f'{str(years)}y')

            # Para eliminar los csv que tengan nula o poca información
            if len(df) > 100:
                df.columns = df.columns.str.lower()
                df.index = df.index.rename("datetime")
                df.to_csv(f"{folder}/{symbol}.csv")
                
        except Exception as e:
            print(f"error with {symbol}")
            print(repr(e))
            continue

# %%
download_stock_data()
# Out:
# ['A' 'AA' 'AA$B' ... 'ZTR' 'ZTS' 'ZX']
# A
# Guardando info en: price_data/A.csv
# [*********************100%***********************]  1 of 1 completed
# AA
# Guardando info en: price_data/AA.csv
# [*********************100%***********************]  1 of 1 completed
# AA$B
# Guardando info en: price_data/AA$B.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AA$B: No data found, symbol may be delisted
# AAC
# Guardando info en: price_data/AAC.csv
# [*********************100%***********************]  1 of 1 completed
# AAN
# Guardando info en: price_data/AAN.csv
# [*********************100%***********************]  1 of 1 completed
# AAP
# Guardando info en: price_data/AAP.csv
# [*********************100%***********************]  1 of 1 completed
# AAT
# Guardando info en: price_data/AAT.csv
# [*********************100%***********************]  1 of 1 completed
# AAV
# Guardando info en: price_data/AAV.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AAV: No data found for this date range, symbol may be delisted
# AB
# Guardando info en: price_data/AB.csv
# [*********************100%***********************]  1 of 1 completed
# ABB
# Guardando info en: price_data/ABB.csv
# [*********************100%***********************]  1 of 1 completed
# ABBV
# Guardando info en: price_data/ABBV.csv
# [*********************100%***********************]  1 of 1 completed
# ABC
# Guardando info en: price_data/ABC.csv
# [*********************100%***********************]  1 of 1 completed
# ABEV
# Guardando info en: price_data/ABEV.csv
# [*********************100%***********************]  1 of 1 completed
# ABG
# Guardando info en: price_data/ABG.csv
# [*********************100%***********************]  1 of 1 completed
# ABM
# Guardando info en: price_data/ABM.csv
# [*********************100%***********************]  1 of 1 completed
# ABR
# Guardando info en: price_data/ABR.csv
# [*********************100%***********************]  1 of 1 completed
# ABR$A
# Guardando info en: price_data/ABR$A.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ABR$A: No data found, symbol may be delisted
# ABR$B
# Guardando info en: price_data/ABR$B.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ABR$B: No data found, symbol may be delisted
# ABR$C
# Guardando info en: price_data/ABR$C.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ABR$C: No data found, symbol may be delisted
# ABRN
# Guardando info en: price_data/ABRN.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ABRN: No data found, symbol may be delisted
# ABT
# Guardando info en: price_data/ABT.csv
# [*********************100%***********************]  1 of 1 completed
# ABX
# Guardando info en: price_data/ABX.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ABX: No data found for this date range, symbol may be delisted
# ACC
# Guardando info en: price_data/ACC.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ACC: No data found, symbol may be delisted
# ACCO
# Guardando info en: price_data/ACCO.csv
# [*********************100%***********************]  1 of 1 completed
# ACE
# Guardando info en: price_data/ACE.csv
# [*********************100%***********************]  1 of 1 completed
# ACG
# Guardando info en: price_data/ACG.csv
# [*********************100%***********************]  1 of 1 completed
# ACH
# Guardando info en: price_data/ACH.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ACH: No data found, symbol may be delisted
# ACI
# Guardando info en: price_data/ACI.csv
# [*********************100%***********************]  1 of 1 completed
# ACM
# Guardando info en: price_data/ACM.csv
# [*********************100%***********************]  1 of 1 completed
# ACMP
# Guardando info en: price_data/ACMP.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ACMP: No data found for this date range, symbol may be delisted
# ACN
# Guardando info en: price_data/ACN.csv
# [*********************100%***********************]  1 of 1 completed
# ACP
# Guardando info en: price_data/ACP.csv
# [*********************100%***********************]  1 of 1 completed
# ACRE
# Guardando info en: price_data/ACRE.csv
# [*********************100%***********************]  1 of 1 completed
# ACT
# Guardando info en: price_data/ACT.csv
# [*********************100%***********************]  1 of 1 completed
# ACW
# Guardando info en: price_data/ACW.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ACW: No data found for this date range, symbol may be delisted
# ADC
# Guardando info en: price_data/ADC.csv
# [*********************100%***********************]  1 of 1 completed
# ADM
# Guardando info en: price_data/ADM.csv
# [*********************100%***********************]  1 of 1 completed
# ADPT
# Guardando info en: price_data/ADPT.csv
# [*********************100%***********************]  1 of 1 completed
# ADS
# Guardando info en: price_data/ADS.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ADS: No data found, symbol may be delisted
# ADT
# Guardando info en: price_data/ADT.csv
# [*********************100%***********************]  1 of 1 completed
# ADX
# Guardando info en: price_data/ADX.csv
# [*********************100%***********************]  1 of 1 completed
# AEB
# Guardando info en: price_data/AEB.csv
# [*********************100%***********************]  1 of 1 completed
# AEC
# Guardando info en: price_data/AEC.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AEC: No data found for this date range, symbol may be delisted
# AED
# Guardando info en: price_data/AED.csv
# [*********************100%***********************]  1 of 1 completed
# AEE
# Guardando info en: price_data/AEE.csv
# [*********************100%***********************]  1 of 1 completed
# AEG
# Guardando info en: price_data/AEG.csv
# [*********************100%***********************]  1 of 1 completed
# AEH
# Guardando info en: price_data/AEH.csv
# [*********************100%***********************]  1 of 1 completed
# AEK
# Guardando info en: price_data/AEK.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AEK: No data found, symbol may be delisted
# AEL
# Guardando info en: price_data/AEL.csv
# [*********************100%***********************]  1 of 1 completed
# AEM
# Guardando info en: price_data/AEM.csv
# [*********************100%***********************]  1 of 1 completed
# AEO
# Guardando info en: price_data/AEO.csv
# [*********************100%***********************]  1 of 1 completed
# AEP
# Guardando info en: price_data/AEP.csv
# [*********************100%***********************]  1 of 1 completed
# AER
# Guardando info en: price_data/AER.csv
# [*********************100%***********************]  1 of 1 completed
# AES
# Guardando info en: price_data/AES.csv
# [*********************100%***********************]  1 of 1 completed
# AES$C
# Guardando info en: price_data/AES$C.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AES$C: No data found, symbol may be delisted
# AET
# Guardando info en: price_data/AET.csv
# [*********************100%***********************]  1 of 1 completed
# AF
# Guardando info en: price_data/AF.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AF: No data found for this date range, symbol may be delisted
# AF$C
# Guardando info en: price_data/AF$C.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AF$C: No data found, symbol may be delisted
# AFA
# Guardando info en: price_data/AFA.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AFA: No data found, symbol may be delisted
# AFB
# Guardando info en: price_data/AFB.csv
# [*********************100%***********************]  1 of 1 completed
# AFC
# Guardando info en: price_data/AFC.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AFC: No data found, symbol may be delisted
# AFG
# Guardando info en: price_data/AFG.csv
# [*********************100%***********************]  1 of 1 completed
# AFGE
# Guardando info en: price_data/AFGE.csv
# [*********************100%***********************]  1 of 1 completed
# AFL
# Guardando info en: price_data/AFL.csv
# [*********************100%***********************]  1 of 1 completed
# AFM
# Guardando info en: price_data/AFM.csv
# [*********************100%***********************]  1 of 1 completed
# AFQ
# Guardando info en: price_data/AFQ.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AFQ: No data found, symbol may be delisted
# AFSD
# Guardando info en: price_data/AFSD.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AFSD: No data found, symbol may be delisted
# AFSI$A
# Guardando info en: price_data/AFSI$A.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AFSI$A: No data found, symbol may be delisted
# AFSI$B
# Guardando info en: price_data/AFSI$B.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AFSI$B: No data found, symbol may be delisted
# AFSI$C
# Guardando info en: price_data/AFSI$C.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AFSI$C: No data found, symbol may be delisted
# AFT
# Guardando info en: price_data/AFT.csv
# [*********************100%***********************]  1 of 1 completed
# AFW
# Guardando info en: price_data/AFW.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AFW: No data found, symbol may be delisted
# AG
# Guardando info en: price_data/AG.csv
# [*********************100%***********************]  1 of 1 completed
# AGC
# Guardando info en: price_data/AGC.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AGC: No data found, symbol may be delisted
# AGCO
# Guardando info en: price_data/AGCO.csv
# [*********************100%***********************]  1 of 1 completed
# AGD
# Guardando info en: price_data/AGD.csv
# [*********************100%***********************]  1 of 1 completed
# AGI
# Guardando info en: price_data/AGI.csv
# [*********************100%***********************]  1 of 1 completed
# AGM
# Guardando info en: price_data/AGM.csv
# [*********************100%***********************]  1 of 1 completed
# AGM$A
# Guardando info en: price_data/AGM$A.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AGM$A: No data found, symbol may be delisted
# AGM$B
# Guardando info en: price_data/AGM$B.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AGM$B: No data found, symbol may be delisted
# AGM$C
# Guardando info en: price_data/AGM$C.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AGM$C: No data found, symbol may be delisted
# AGM.A
# Guardando info en: price_data/AGM.A.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AGM.A: No data found, symbol may be delisted
# AGN
# Guardando info en: price_data/AGN.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AGN: No data found, symbol may be delisted
# AGO
# Guardando info en: price_data/AGO.csv
# [*********************100%***********************]  1 of 1 completed
# AGO$B
# Guardando info en: price_data/AGO$B.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AGO$B: No data found, symbol may be delisted
# AGO$E
# Guardando info en: price_data/AGO$E.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AGO$E: No data found, symbol may be delisted
# AGO$F
# Guardando info en: price_data/AGO$F.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AGO$F: No data found, symbol may be delisted
# AGRO
# Guardando info en: price_data/AGRO.csv
# [*********************100%***********************]  1 of 1 completed
# AGU
# Guardando info en: price_data/AGU.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AGU: No data found for this date range, symbol may be delisted
# AGX
# Guardando info en: price_data/AGX.csv
# [*********************100%***********************]  1 of 1 completed
# AHC
# Guardando info en: price_data/AHC.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AHC: No data found, symbol may be delisted
# AHH
# Guardando info en: price_data/AHH.csv
# [*********************100%***********************]  1 of 1 completed
# AHL
# Guardando info en: price_data/AHL.csv
# [*********************100%***********************]  1 of 1 completed
# AHL$A
# Guardando info en: price_data/AHL$A.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AHL$A: No data found, symbol may be delisted
# AHL$B
# Guardando info en: price_data/AHL$B.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AHL$B: No data found, symbol may be delisted
# AHL$C
# Guardando info en: price_data/AHL$C.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AHL$C: No data found, symbol may be delisted
# AHP
# Guardando info en: price_data/AHP.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AHP: No data found for this date range, symbol may be delisted
# AHS
# Guardando info en: price_data/AHS.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AHS: No data found for this date range, symbol may be delisted
# AHT
# Guardando info en: price_data/AHT.csv
# [*********************100%***********************]  1 of 1 completed
# AHT$A
# Guardando info en: price_data/AHT$A.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AHT$A: No data found, symbol may be delisted
# AHT$D
# Guardando info en: price_data/AHT$D.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AHT$D: No data found, symbol may be delisted
# AHT$E
# Guardando info en: price_data/AHT$E.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AHT$E: No data found, symbol may be delisted
# AI
# Guardando info en: price_data/AI.csv
# [*********************100%***********************]  1 of 1 completed
# AIB
# Guardando info en: price_data/AIB.csv
# [*********************100%***********************]  1 of 1 completed
# AIF
# Guardando info en: price_data/AIF.csv
# [*********************100%***********************]  1 of 1 completed
# AIG
# Guardando info en: price_data/AIG.csv
# [*********************100%***********************]  1 of 1 completed
# AIG.W
# Guardando info en: price_data/AIG.W.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AIG.W: No data found, symbol may be delisted
# AIN
# Guardando info en: price_data/AIN.csv
# [*********************100%***********************]  1 of 1 completed
# AIR
# Guardando info en: price_data/AIR.csv
# [*********************100%***********************]  1 of 1 completed
# AIT
# Guardando info en: price_data/AIT.csv
# [*********************100%***********************]  1 of 1 completed
# AIV
# Guardando info en: price_data/AIV.csv
# [*********************100%***********************]  1 of 1 completed
# AIV$A
# Guardando info en: price_data/AIV$A.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AIV$A: No data found, symbol may be delisted
# AIV$Z
# Guardando info en: price_data/AIV$Z.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AIV$Z: No data found, symbol may be delisted
# AIW
# Guardando info en: price_data/AIW.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AIW: No data found, symbol may be delisted
# AIY
# Guardando info en: price_data/AIY.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AIY: No data found, symbol may be delisted
# AIZ
# Guardando info en: price_data/AIZ.csv
# [*********************100%***********************]  1 of 1 completed
# AJG
# Guardando info en: price_data/AJG.csv
# [*********************100%***********************]  1 of 1 completed
# AKO.A
# Guardando info en: price_data/AKO.A.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AKO.A: No data found, symbol may be delisted
# AKO.B
# Guardando info en: price_data/AKO.B.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AKO.B: No data found, symbol may be delisted
# AKP
# Guardando info en: price_data/AKP.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AKP: No data found, symbol may be delisted
# AKR
# Guardando info en: price_data/AKR.csv
# [*********************100%***********************]  1 of 1 completed
# AKS
# Guardando info en: price_data/AKS.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AKS: No data found, symbol may be delisted
# AL
# Guardando info en: price_data/AL.csv
# [*********************100%***********************]  1 of 1 completed
# ALB
# Guardando info en: price_data/ALB.csv
# [*********************100%***********************]  1 of 1 completed
# ALDW
# Guardando info en: price_data/ALDW.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ALDW: No data found for this date range, symbol may be delisted
# ALE
# Guardando info en: price_data/ALE.csv
# [*********************100%***********************]  1 of 1 completed
# ALEX
# Guardando info en: price_data/ALEX.csv
# [*********************100%***********************]  1 of 1 completed
# ALG
# Guardando info en: price_data/ALG.csv
# [*********************100%***********************]  1 of 1 completed
# ALJ
# Guardando info en: price_data/ALJ.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ALJ: No data found for this date range, symbol may be delisted
# ALK
# Guardando info en: price_data/ALK.csv
# [*********************100%***********************]  1 of 1 completed
# ALL
# Guardando info en: price_data/ALL.csv
# [*********************100%***********************]  1 of 1 completed
# ALL$A
# Guardando info en: price_data/ALL$A.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ALL$A: No data found, symbol may be delisted
# ALL$B
# Guardando info en: price_data/ALL$B.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ALL$B: No data found, symbol may be delisted
# ALL$C
# Guardando info en: price_data/ALL$C.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ALL$C: No data found, symbol may be delisted
# ALL$D
# Guardando info en: price_data/ALL$D.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ALL$D: No data found, symbol may be delisted
# ALL$E
# Guardando info en: price_data/ALL$E.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ALL$E: No data found, symbol may be delisted
# ALL$F
# Guardando info en: price_data/ALL$F.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ALL$F: No data found, symbol may be delisted
# ALLE
# Guardando info en: price_data/ALLE.csv
# [*********************100%***********************]  1 of 1 completed
# ALLY
# Guardando info en: price_data/ALLY.csv
# [*********************100%***********************]  1 of 1 completed
# ALLY$A
# Guardando info en: price_data/ALLY$A.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ALLY$A: No data found, symbol may be delisted
# ALLY$B
# Guardando info en: price_data/ALLY$B.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ALLY$B: No data found, symbol may be delisted
# ALP$N
# Guardando info en: price_data/ALP$N.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ALP$N: No data found, symbol may be delisted
# ALP$O
# Guardando info en: price_data/ALP$O.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ALP$O: No data found, symbol may be delisted
# ALP$P
# Guardando info en: price_data/ALP$P.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ALP$P: No data found, symbol may be delisted
# ALR
# Guardando info en: price_data/ALR.csv
# [*********************100%***********************]  1 of 1 completed
# ALR$B
# Guardando info en: price_data/ALR$B.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ALR$B: No data found, symbol may be delisted
# ALSN
# Guardando info en: price_data/ALSN.csv
# [*********************100%***********************]  1 of 1 completed
# ALU
# Guardando info en: price_data/ALU.csv
# [*********************100%***********************]  1 of 1 completed
# ALV
# Guardando info en: price_data/ALV.csv
# [*********************100%***********************]  1 of 1 completed
# ALX
# Guardando info en: price_data/ALX.csv
# [*********************100%***********************]  1 of 1 completed
# AM
# Guardando info en: price_data/AM.csv
# [*********************100%***********************]  1 of 1 completed
# AMBR
# Guardando info en: price_data/AMBR.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AMBR: No data found, symbol may be delisted
# AMC
# Guardando info en: price_data/AMC.csv
# [*********************100%***********************]  1 of 1 completed
# AME
# Guardando info en: price_data/AME.csv
# [*********************100%***********************]  1 of 1 completed
# AMFW
# Guardando info en: price_data/AMFW.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AMFW: No data found, symbol may be delisted
# AMG
# Guardando info en: price_data/AMG.csv
# [*********************100%***********************]  1 of 1 completed
# AMH
# Guardando info en: price_data/AMH.csv
# [*********************100%***********************]  1 of 1 completed
# AMH$A
# Guardando info en: price_data/AMH$A.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AMH$A: No data found, symbol may be delisted
# AMH$B
# Guardando info en: price_data/AMH$B.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AMH$B: No data found, symbol may be delisted
# AMH$C
# Guardando info en: price_data/AMH$C.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AMH$C: No data found, symbol may be delisted
# AMID
# Guardando info en: price_data/AMID.csv
# [*********************100%***********************]  1 of 1 completed
# AMP
# Guardando info en: price_data/AMP.csv
# [*********************100%***********************]  1 of 1 completed
# AMRC
# Guardando info en: price_data/AMRC.csv
# [*********************100%***********************]  1 of 1 completed
# AMRE
# Guardando info en: price_data/AMRE.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AMRE: No data found for this date range, symbol may be delisted
# AMT
# Guardando info en: price_data/AMT.csv
# [*********************100%***********************]  1 of 1 completed
# AMT$A
# Guardando info en: price_data/AMT$A.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AMT$A: No data found, symbol may be delisted
# AMTD
# Guardando info en: price_data/AMTD.csv
# [*********************100%***********************]  1 of 1 completed
# AMTG
# Guardando info en: price_data/AMTG.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AMTG: No data found for this date range, symbol may be delisted
# AMTG$A
# Guardando info en: price_data/AMTG$A.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AMTG$A: No data found, symbol may be delisted
# AMX
# Guardando info en: price_data/AMX.csv
# [*********************100%***********************]  1 of 1 completed
# AN
# Guardando info en: price_data/AN.csv
# [*********************100%***********************]  1 of 1 completed
# ANET
# Guardando info en: price_data/ANET.csv
# [*********************100%***********************]  1 of 1 completed
# ANF
# Guardando info en: price_data/ANF.csv
# [*********************100%***********************]  1 of 1 completed
# ANFI
# Guardando info en: price_data/ANFI.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ANFI: No data found, symbol may be delisted
# ANH
# Guardando info en: price_data/ANH.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ANH: No data found, symbol may be delisted
# ANH$A
# Guardando info en: price_data/ANH$A.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ANH$A: No data found, symbol may be delisted
# ANH$B
# Guardando info en: price_data/ANH$B.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ANH$B: No data found, symbol may be delisted
# ANN
# Guardando info en: price_data/ANN.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ANN: No data found for this date range, symbol may be delisted
# ANR
# Guardando info en: price_data/ANR.csv
# [*********************100%***********************]  1 of 1 completed
# ANTM
# Guardando info en: price_data/ANTM.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ANTM: No data found, symbol may be delisted
# ANW
# Guardando info en: price_data/ANW.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ANW: No data found for this date range, symbol may be delisted
# AOD
# Guardando info en: price_data/AOD.csv
# [*********************100%***********************]  1 of 1 completed
# AOI
# Guardando info en: price_data/AOI.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AOI: No data found for this date range, symbol may be delisted
# AOL
# Guardando info en: price_data/AOL.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AOL: No data found for this date range, symbol may be delisted
# AON
# Guardando info en: price_data/AON.csv
# [*********************100%***********************]  1 of 1 completed
# AOS
# Guardando info en: price_data/AOS.csv
# [*********************100%***********************]  1 of 1 completed
# AP
# Guardando info en: price_data/AP.csv
# [*********************100%***********************]  1 of 1 completed
# APA
# Guardando info en: price_data/APA.csv
# [*********************100%***********************]  1 of 1 completed
# APAM
# Guardando info en: price_data/APAM.csv
# [*********************100%***********************]  1 of 1 completed
# APB
# Guardando info en: price_data/APB.csv
# [*********************100%***********************]  1 of 1 completed
# APC
# Guardando info en: price_data/APC.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - APC: No data found, symbol may be delisted
# APD
# Guardando info en: price_data/APD.csv
# [*********************100%***********************]  1 of 1 completed
# APF
# Guardando info en: price_data/APF.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - APF: No data found, symbol may be delisted
# APH
# Guardando info en: price_data/APH.csv
# [*********************100%***********************]  1 of 1 completed
# APL
# Guardando info en: price_data/APL.csv
# [*********************100%***********************]  1 of 1 completed
# APL$E
# Guardando info en: price_data/APL$E.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - APL$E: No data found, symbol may be delisted
# APO
# Guardando info en: price_data/APO.csv
# [*********************100%***********************]  1 of 1 completed
# APU
# Guardando info en: price_data/APU.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - APU: No data found, symbol may be delisted
# AR
# Guardando info en: price_data/AR.csv
# [*********************100%***********************]  1 of 1 completed
# ARC
# Guardando info en: price_data/ARC.csv
# [*********************100%***********************]  1 of 1 completed
# ARCO
# Guardando info en: price_data/ARCO.csv
# [*********************100%***********************]  1 of 1 completed
# ARCX
# Guardando info en: price_data/ARCX.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ARCX: No data found for this date range, symbol may be delisted
# ARDC
# Guardando info en: price_data/ARDC.csv
# [*********************100%***********************]  1 of 1 completed
# ARE
# Guardando info en: price_data/ARE.csv
# [*********************100%***********************]  1 of 1 completed
# ARE$E
# Guardando info en: price_data/ARE$E.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ARE$E: No data found, symbol may be delisted
# ARES
# Guardando info en: price_data/ARES.csv
# [*********************100%***********************]  1 of 1 completed
# ARG
# Guardando info en: price_data/ARG.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ARG: No data found for this date range, symbol may be delisted
# ARH$C
# Guardando info en: price_data/ARH$C.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ARH$C: No data found, symbol may be delisted
# ARI
# Guardando info en: price_data/ARI.csv
# [*********************100%***********************]  1 of 1 completed
# ARI$A
# Guardando info en: price_data/ARI$A.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ARI$A: No data found, symbol may be delisted
# ARL
# Guardando info en: price_data/ARL.csv
# [*********************100%***********************]  1 of 1 completed
# ARMF
# Guardando info en: price_data/ARMF.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ARMF: No data found for this date range, symbol may be delisted
# ARMK
# Guardando info en: price_data/ARMK.csv
# [*********************100%***********************]  1 of 1 completed
# ARN
# Guardando info en: price_data/ARN.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ARN: No data found for this date range, symbol may be delisted
# ARO
# Guardando info en: price_data/ARO.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ARO: No data found for this date range, symbol may be delisted
# ARP
# Guardando info en: price_data/ARP.csv
# [*********************100%***********************]  1 of 1 completed
# ARP$D
# Guardando info en: price_data/ARP$D.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ARP$D: No data found, symbol may be delisted
# ARPI
# Guardando info en: price_data/ARPI.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ARPI: No data found for this date range, symbol may be delisted
# ARR
# Guardando info en: price_data/ARR.csv
# [*********************100%***********************]  1 of 1 completed
# ARR$A
# Guardando info en: price_data/ARR$A.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ARR$A: No data found, symbol may be delisted
# ARR$B
# Guardando info en: price_data/ARR$B.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ARR$B: No data found, symbol may be delisted
# ARU
# Guardando info en: price_data/ARU.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ARU: No data found, symbol may be delisted
# ARW
# Guardando info en: price_data/ARW.csv
# [*********************100%***********************]  1 of 1 completed
# ARY
# Guardando info en: price_data/ARY.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ARY: No data found, symbol may be delisted
# ASA
# Guardando info en: price_data/ASA.csv
# [*********************100%***********************]  1 of 1 completed
# ASB
# Guardando info en: price_data/ASB.csv
# [*********************100%***********************]  1 of 1 completed
# ASB$B
# Guardando info en: price_data/ASB$B.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ASB$B: No data found, symbol may be delisted
# ASC
# Guardando info en: price_data/ASC.csv
# [*********************100%***********************]  1 of 1 completed
# ASG
# Guardando info en: price_data/ASG.csv
# [*********************100%***********************]  1 of 1 completed
# ASGN
# Guardando info en: price_data/ASGN.csv
# [*********************100%***********************]  1 of 1 completed
# ASH
# Guardando info en: price_data/ASH.csv
# [*********************100%***********************]  1 of 1 completed
# ASPN
# Guardando info en: price_data/ASPN.csv
# [*********************100%***********************]  1 of 1 completed
# ASR
# Guardando info en: price_data/ASR.csv
# [*********************100%***********************]  1 of 1 completed
# ASX
# Guardando info en: price_data/ASX.csv
# [*********************100%***********************]  1 of 1 completed
# AT
# Guardando info en: price_data/AT.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AT: No data found, symbol may be delisted
# ATE
# Guardando info en: price_data/ATE.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ATE: No data found for this date range, symbol may be delisted
# ATEN
# Guardando info en: price_data/ATEN.csv
# [*********************100%***********************]  1 of 1 completed
# ATHM
# Guardando info en: price_data/ATHM.csv
# [*********************100%***********************]  1 of 1 completed
# ATI
# Guardando info en: price_data/ATI.csv
# [*********************100%***********************]  1 of 1 completed
# ATK
# Guardando info en: price_data/ATK.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ATK: No data found for this date range, symbol may be delisted
# ATLS
# Guardando info en: price_data/ATLS.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ATLS: No data found, symbol may be delisted
# ATO
# Guardando info en: price_data/ATO.csv
# [*********************100%***********************]  1 of 1 completed
# ATR
# Guardando info en: price_data/ATR.csv
# [*********************100%***********************]  1 of 1 completed
# ATTO
# Guardando info en: price_data/ATTO.csv
# [*********************100%***********************]  1 of 1 completed
# ATU
# Guardando info en: price_data/ATU.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ATU: No data found, symbol may be delisted
# ATV
# Guardando info en: price_data/ATV.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ATV: No data found, symbol may be delisted
# ATW
# Guardando info en: price_data/ATW.csv
# [*********************100%***********************]  1 of 1 completed
# AU
# Guardando info en: price_data/AU.csv
# [*********************100%***********************]  1 of 1 completed
# AUO
# Guardando info en: price_data/AUO.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AUO: No data found, symbol may be delisted
# AUQ
# Guardando info en: price_data/AUQ.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AUQ: No data found for this date range, symbol may be delisted
# AUY
# Guardando info en: price_data/AUY.csv
# [*********************100%***********************]  1 of 1 completed
# AV
# Guardando info en: price_data/AV.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AV: No data found for this date range, symbol may be delisted
# AVA
# Guardando info en: price_data/AVA.csv
# [*********************100%***********************]  1 of 1 completed
# AVAL
# Guardando info en: price_data/AVAL.csv
# [*********************100%***********************]  1 of 1 completed
# AVB
# Guardando info en: price_data/AVB.csv
# [*********************100%***********************]  1 of 1 completed
# AVD
# Guardando info en: price_data/AVD.csv
# [*********************100%***********************]  1 of 1 completed
# AVG
# Guardando info en: price_data/AVG.csv
# [*********************100%***********************]  1 of 1 completed
# AVH
# Guardando info en: price_data/AVH.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AVH: No data found, symbol may be delisted
# AVIV
# Guardando info en: price_data/AVIV.csv
# [*********************100%***********************]  1 of 1 completed
# AVK
# Guardando info en: price_data/AVK.csv
# [*********************100%***********************]  1 of 1 completed
# AVOL
# Guardando info en: price_data/AVOL.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AVOL: No data found, symbol may be delisted
# AVP
# Guardando info en: price_data/AVP.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AVP: No data found, symbol may be delisted
# AVT
# Guardando info en: price_data/AVT.csv
# [*********************100%***********************]  1 of 1 completed
# AVV
# Guardando info en: price_data/AVV.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AVV: No data found, symbol may be delisted
# AVX
# Guardando info en: price_data/AVX.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AVX: No data found, symbol may be delisted
# AVY
# Guardando info en: price_data/AVY.csv
# [*********************100%***********************]  1 of 1 completed
# AWF
# Guardando info en: price_data/AWF.csv
# [*********************100%***********************]  1 of 1 completed
# AWH
# Guardando info en: price_data/AWH.csv
# [*********************100%***********************]  1 of 1 completed
# AWI
# Guardando info en: price_data/AWI.csv
# [*********************100%***********************]  1 of 1 completed
# AWK
# Guardando info en: price_data/AWK.csv
# [*********************100%***********************]  1 of 1 completed
# AWP
# Guardando info en: price_data/AWP.csv
# [*********************100%***********************]  1 of 1 completed
# AWR
# Guardando info en: price_data/AWR.csv
# [*********************100%***********************]  1 of 1 completed
# AXE
# Guardando info en: price_data/AXE.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AXE: No data found, symbol may be delisted
# AXL
# Guardando info en: price_data/AXL.csv
# [*********************100%***********************]  1 of 1 completed
# AXLL
# Guardando info en: price_data/AXLL.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AXLL: No data found for this date range, symbol may be delisted
# AXP
# Guardando info en: price_data/AXP.csv
# [*********************100%***********************]  1 of 1 completed
# AXR
# Guardando info en: price_data/AXR.csv
# [*********************100%***********************]  1 of 1 completed
# AXS
# Guardando info en: price_data/AXS.csv
# [*********************100%***********************]  1 of 1 completed
# AXS$C
# Guardando info en: price_data/AXS$C.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AXS$C: No data found, symbol may be delisted
# AXS$D
# Guardando info en: price_data/AXS$D.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AXS$D: No data found, symbol may be delisted
# AXTA
# Guardando info en: price_data/AXTA.csv
# [*********************100%***********************]  1 of 1 completed
# AYI
# Guardando info en: price_data/AYI.csv
# [*********************100%***********************]  1 of 1 completed
# AYN
# Guardando info en: price_data/AYN.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AYN: No data found for this date range, symbol may be delisted
# AYR
# Guardando info en: price_data/AYR.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AYR: No data found, symbol may be delisted
# AZN
# Guardando info en: price_data/AZN.csv
# [*********************100%***********************]  1 of 1 completed
# AZO
# Guardando info en: price_data/AZO.csv
# [*********************100%***********************]  1 of 1 completed
# AZZ
# Guardando info en: price_data/AZZ.csv
# [*********************100%***********************]  1 of 1 completed
# B
# Guardando info en: price_data/B.csv
# [*********************100%***********************]  1 of 1 completed
# BA
# Guardando info en: price_data/BA.csv
# [*********************100%***********************]  1 of 1 completed
# BABA
# Guardando info en: price_data/BABA.csv
# [*********************100%***********************]  1 of 1 completed
# BAC
# Guardando info en: price_data/BAC.csv
# [*********************100%***********************]  1 of 1 completed
# BAC$D
# Guardando info en: price_data/BAC$D.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BAC$D: No data found, symbol may be delisted
# BAC$E
# Guardando info en: price_data/BAC$E.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BAC$E: No data found, symbol may be delisted
# BAC$I
# Guardando info en: price_data/BAC$I.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BAC$I: No data found, symbol may be delisted
# BAC$L
# Guardando info en: price_data/BAC$L.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BAC$L: No data found, symbol may be delisted
# BAC$W
# Guardando info en: price_data/BAC$W.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BAC$W: No data found, symbol may be delisted
# BAC$Z
# Guardando info en: price_data/BAC$Z.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BAC$Z: No data found, symbol may be delisted
# BAC.A
# Guardando info en: price_data/BAC.A.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BAC.A: No data found, symbol may be delisted
# BAC.B
# Guardando info en: price_data/BAC.B.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BAC.B: No data found for this date range, symbol may be delisted
# BAF
# Guardando info en: price_data/BAF.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BAF: No data found, symbol may be delisted
# BAH
# Guardando info en: price_data/BAH.csv
# [*********************100%***********************]  1 of 1 completed
# BAK
# Guardando info en: price_data/BAK.csv
# [*********************100%***********************]  1 of 1 completed
# BALT
# Guardando info en: price_data/BALT.csv
# [*********************100%***********************]  1 of 1 completed
# BAM
# Guardando info en: price_data/BAM.csv
# [*********************100%***********************]  1 of 1 completed
# BANC
# Guardando info en: price_data/BANC.csv
# [*********************100%***********************]  1 of 1 completed
# BANC$C
# Guardando info en: price_data/BANC$C.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BANC$C: No data found, symbol may be delisted
# BAP
# Guardando info en: price_data/BAP.csv
# [*********************100%***********************]  1 of 1 completed
# BAS
# Guardando info en: price_data/BAS.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BAS: No data found, symbol may be delisted
# BAX
# Guardando info en: price_data/BAX.csv
# [*********************100%***********************]  1 of 1 completed
# BBD
# Guardando info en: price_data/BBD.csv
# [*********************100%***********************]  1 of 1 completed
# BBDO
# Guardando info en: price_data/BBDO.csv
# [*********************100%***********************]  1 of 1 completed
# BBF
# Guardando info en: price_data/BBF.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BBF: No data found, symbol may be delisted
# BBG
# Guardando info en: price_data/BBG.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BBG: No data found for this date range, symbol may be delisted
# BBK
# Guardando info en: price_data/BBK.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BBK: No data found, symbol may be delisted
# BBL
# Guardando info en: price_data/BBL.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BBL: No data found, symbol may be delisted
# BBN
# Guardando info en: price_data/BBN.csv
# [*********************100%***********************]  1 of 1 completed
# BBT
# Guardando info en: price_data/BBT.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BBT: No data found, symbol may be delisted
# BBT$D
# Guardando info en: price_data/BBT$D.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BBT$D: No data found, symbol may be delisted
# BBT$E
# Guardando info en: price_data/BBT$E.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BBT$E: No data found, symbol may be delisted
# BBT$F
# Guardando info en: price_data/BBT$F.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BBT$F: No data found, symbol may be delisted
# BBT$G
# Guardando info en: price_data/BBT$G.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BBT$G: No data found, symbol may be delisted
# BBVA
# Guardando info en: price_data/BBVA.csv
# [*********************100%***********************]  1 of 1 completed
# BBW
# Guardando info en: price_data/BBW.csv
# [*********************100%***********************]  1 of 1 completed
# BBX
# Guardando info en: price_data/BBX.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BBX: No data found, symbol may be delisted
# BBY
# Guardando info en: price_data/BBY.csv
# [*********************100%***********************]  1 of 1 completed
# BC
# Guardando info en: price_data/BC.csv
# [*********************100%***********************]  1 of 1 completed
# BCA
# Guardando info en: price_data/BCA.csv
# [*********************100%***********************]  1 of 1 completed
# BCC
# Guardando info en: price_data/BCC.csv
# [*********************100%***********************]  1 of 1 completed
# BCE
# Guardando info en: price_data/BCE.csv
# [*********************100%***********************]  1 of 1 completed
# BCEI
# Guardando info en: price_data/BCEI.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BCEI: No data found, symbol may be delisted
# BCH
# Guardando info en: price_data/BCH.csv
# [*********************100%***********************]  1 of 1 completed
# BCO
# Guardando info en: price_data/BCO.csv
# [*********************100%***********************]  1 of 1 completed
# BCR
# Guardando info en: price_data/BCR.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BCR: No data found for this date range, symbol may be delisted
# BCRH
# Guardando info en: price_data/BCRH.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BCRH: No data found, symbol may be delisted
# BCS
# Guardando info en: price_data/BCS.csv
# [*********************100%***********************]  1 of 1 completed
# BCS$
# ...
# [*********************100%***********************]  1 of 1 completed
# WGP
# Guardando info en: price_data/WGP.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - WGP: No data found, symbol may be delisted
# WHG
# Guardando info en: price_data/WHG.csv
# [*********************100%***********************]  1 of 1 completed
# WHR
# Guardando info en: price_data/WHR.csv
# [*********************100%***********************]  1 of 1 completed
# WHX
# Guardando info en: price_data/WHX.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - WHX: No data found for this date range, symbol may be delisted
# WHZ
# Guardando info en: price_data/WHZ.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - WHZ: No data found, symbol may be delisted
# WIA
# Guardando info en: price_data/WIA.csv
# [*********************100%***********************]  1 of 1 completed
# WIT
# Guardando info en: price_data/WIT.csv
# [*********************100%***********************]  1 of 1 completed
# WIW
# Guardando info en: price_data/WIW.csv
# [*********************100%***********************]  1 of 1 completed
# WK
# Guardando info en: price_data/WK.csv
# [*********************100%***********************]  1 of 1 completed
# WLH
# Guardando info en: price_data/WLH.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - WLH: No data found, symbol may be delisted
# WLK
# Guardando info en: price_data/WLK.csv
# [*********************100%***********************]  1 of 1 completed
# WLKP
# Guardando info en: price_data/WLKP.csv
# [*********************100%***********************]  1 of 1 completed
# WLL
# Guardando info en: price_data/WLL.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - WLL: No data found, symbol may be delisted
# WLT
# Guardando info en: price_data/WLT.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - WLT: No data found for this date range, symbol may be delisted
# WM
# Guardando info en: price_data/WM.csv
# [*********************100%***********************]  1 of 1 completed
# WMB
# Guardando info en: price_data/WMB.csv
# [*********************100%***********************]  1 of 1 completed
# WMC
# Guardando info en: price_data/WMC.csv
# [*********************100%***********************]  1 of 1 completed
# WMK
# Guardando info en: price_data/WMK.csv
# [*********************100%***********************]  1 of 1 completed
# WMLP
# Guardando info en: price_data/WMLP.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - WMLP: No data found for this date range, symbol may be delisted
# WMS
# Guardando info en: price_data/WMS.csv
# [*********************100%***********************]  1 of 1 completed
# WMT
# Guardando info en: price_data/WMT.csv
# [*********************100%***********************]  1 of 1 completed
# WNC
# Guardando info en: price_data/WNC.csv
# [*********************100%***********************]  1 of 1 completed
# WNR
# Guardando info en: price_data/WNR.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - WNR: No data found for this date range, symbol may be delisted
# WNRL
# Guardando info en: price_data/WNRL.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - WNRL: No data found for this date range, symbol may be delisted
# WNS
# Guardando info en: price_data/WNS.csv
# [*********************100%***********************]  1 of 1 completed
# WOR
# Guardando info en: price_data/WOR.csv
# [*********************100%***********************]  1 of 1 completed
# WPC
# Guardando info en: price_data/WPC.csv
# [*********************100%***********************]  1 of 1 completed
# WPG
# Guardando info en: price_data/WPG.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - WPG: No data found, symbol may be delisted
# WPP
# Guardando info en: price_data/WPP.csv
# [*********************100%***********************]  1 of 1 completed
# WPT
# Guardando info en: price_data/WPT.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - WPT: No data found for this date range, symbol may be delisted
# WPX
# Guardando info en: price_data/WPX.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - WPX: No data found, symbol may be delisted
# WPZ
# Guardando info en: price_data/WPZ.csv
# [*********************100%***********************]  1 of 1 completed
# WR
# Guardando info en: price_data/WR.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - WR: No data found for this date range, symbol may be delisted
# WRB
# Guardando info en: price_data/WRB.csv
# [*********************100%***********************]  1 of 1 completed
# WRB$B
# Guardando info en: price_data/WRB$B.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - WRB$B: No data found, symbol may be delisted
# WRE
# Guardando info en: price_data/WRE.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - WRE: No data found, symbol may be delisted
# WRI
# Guardando info en: price_data/WRI.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - WRI: No data found, symbol may be delisted
# WRI$F
# Guardando info en: price_data/WRI$F.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - WRI$F: No data found, symbol may be delisted
# WRT
# Guardando info en: price_data/WRT.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - WRT: No data found, symbol may be delisted
# WSH
# Guardando info en: price_data/WSH.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - WSH: No data found for this date range, symbol may be delisted
# WSM
# Guardando info en: price_data/WSM.csv
# [*********************100%***********************]  1 of 1 completed
# WSO
# Guardando info en: price_data/WSO.csv
# [*********************100%***********************]  1 of 1 completed
# WSO.B
# Guardando info en: price_data/WSO.B.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - WSO.B: No data found, symbol may be delisted
# WSR
# Guardando info en: price_data/WSR.csv
# [*********************100%***********************]  1 of 1 completed
# WST
# Guardando info en: price_data/WST.csv
# [*********************100%***********************]  1 of 1 completed
# WTI
# Guardando info en: price_data/WTI.csv
# [*********************100%***********************]  1 of 1 completed
# WTM
# Guardando info en: price_data/WTM.csv
# [*********************100%***********************]  1 of 1 completed
# WTR
# Guardando info en: price_data/WTR.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - WTR: No data found, symbol may be delisted
# WTS
# Guardando info en: price_data/WTS.csv
# [*********************100%***********************]  1 of 1 completed
# WTW
# Guardando info en: price_data/WTW.csv
# [*********************100%***********************]  1 of 1 completed
# WU
# Guardando info en: price_data/WU.csv
# [*********************100%***********************]  1 of 1 completed
# WUBA
# Guardando info en: price_data/WUBA.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - WUBA: No data found, symbol may be delisted
# WWAV
# Guardando info en: price_data/WWAV.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - WWAV: No data found for this date range, symbol may be delisted
# WWE
# Guardando info en: price_data/WWE.csv
# [*********************100%***********************]  1 of 1 completed
# WWW
# Guardando info en: price_data/WWW.csv
# [*********************100%***********************]  1 of 1 completed
# WX
# Guardando info en: price_data/WX.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - WX: No data found for this date range, symbol may be delisted
# WY
# Guardando info en: price_data/WY.csv
# [*********************100%***********************]  1 of 1 completed
# WY$A
# Guardando info en: price_data/WY$A.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - WY$A: No data found, symbol may be delisted
# WYN
# Guardando info en: price_data/WYN.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - WYN: No data found for this date range, symbol may be delisted
# X
# Guardando info en: price_data/X.csv
# [*********************100%***********************]  1 of 1 completed
# XCO
# Guardando info en: price_data/XCO.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - XCO: No data found for this date range, symbol may be delisted
# XEC
# Guardando info en: price_data/XEC.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - XEC: No data found, symbol may be delisted
# XEL
# Guardando info en: price_data/XEL.csv
# [*********************100%***********************]  1 of 1 completed
# XIN
# Guardando info en: price_data/XIN.csv
# [*********************100%***********************]  1 of 1 completed
# XKE
# Guardando info en: price_data/XKE.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - XKE: No data found for this date range, symbol may be delisted
# XL
# Guardando info en: price_data/XL.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - XL: No data found, symbol may be delisted
# XLS
# Guardando info en: price_data/XLS.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - XLS: No data found for this date range, symbol may be delisted
# XNY
# Guardando info en: price_data/XNY.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - XNY: No data found for this date range, symbol may be delisted
# XOM
# Guardando info en: price_data/XOM.csv
# [*********************100%***********************]  1 of 1 completed
# XON
# Guardando info en: price_data/XON.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - XON: No data found, symbol may be delisted
# XOXO
# Guardando info en: price_data/XOXO.csv
# [*********************100%***********************]  1 of 1 completed
# XPO
# Guardando info en: price_data/XPO.csv
# [*********************100%***********************]  1 of 1 completed
# XRM
# Guardando info en: price_data/XRM.csv
# [*********************100%***********************]  1 of 1 completed
# XRS
# Guardando info en: price_data/XRS.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - XRS: No data found for this date range, symbol may be delisted
# XRX
# Guardando info en: price_data/XRX.csv
# [*********************100%***********************]  1 of 1 completed
# XUE
# Guardando info en: price_data/XUE.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - XUE: No data found for this date range, symbol may be delisted
# XYL
# Guardando info en: price_data/XYL.csv
# [*********************100%***********************]  1 of 1 completed
# Y
# Guardando info en: price_data/Y.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - Y: No data found, symbol may be delisted
# YDKN
# Guardando info en: price_data/YDKN.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - YDKN: No data found for this date range, symbol may be delisted
# YELP
# Guardando info en: price_data/YELP.csv
# [*********************100%***********************]  1 of 1 completed
# YGE
# Guardando info en: price_data/YGE.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - YGE: No data found for this date range, symbol may be delisted
# YOKU
# Guardando info en: price_data/YOKU.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - YOKU: No data found for this date range, symbol may be delisted
# YPF
# Guardando info en: price_data/YPF.csv
# [*********************100%***********************]  1 of 1 completed
# YUM
# Guardando info en: price_data/YUM.csv
# [*********************100%***********************]  1 of 1 completed
# YUME
# Guardando info en: price_data/YUME.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - YUME: No data found for this date range, symbol may be delisted
# YZC
# Guardando info en: price_data/YZC.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - YZC: No data found for this date range, symbol may be delisted
# ZA
# Guardando info en: price_data/ZA.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ZA: No data found for this date range, symbol may be delisted
# ZAYO
# Guardando info en: price_data/ZAYO.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ZAYO: No data found, symbol may be delisted
# ZB$A
# Guardando info en: price_data/ZB$A.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ZB$A: No data found, symbol may be delisted
# ZB$F
# Guardando info en: price_data/ZB$F.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ZB$F: No data found, symbol may be delisted
# ZB$G
# Guardando info en: price_data/ZB$G.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ZB$G: No data found, symbol may be delisted
# ZB$H
# Guardando info en: price_data/ZB$H.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ZB$H: No data found, symbol may be delisted
# ZBK
# Guardando info en: price_data/ZBK.csv
# [*********************100%***********************]  1 of 1 completed
# ZEN
# Guardando info en: price_data/ZEN.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ZEN: No data found, symbol may be delisted
# ZEP
# Guardando info en: price_data/ZEP.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ZEP: No data found for this date range, symbol may be delisted
# ZF
# Guardando info en: price_data/ZF.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ZF: No data found, symbol may be delisted
# ZFC
# Guardando info en: price_data/ZFC.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ZFC: No data found for this date range, symbol may be delisted
# ZMH
# Guardando info en: price_data/ZMH.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ZMH: No data found for this date range, symbol may be delisted
# ZNH
# Guardando info en: price_data/ZNH.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ZNH: No data found, symbol may be delisted
# ZOES
# Guardando info en: price_data/ZOES.csv
# [*********************100%***********************]  1 of 1 completed
# ZPIN
# Guardando info en: price_data/ZPIN.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ZPIN: No data found for this date range, symbol may be delisted
# ZQK
# Guardando info en: price_data/ZQK.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ZQK: No data found for this date range, symbol may be delisted
# ZTR
# Guardando info en: price_data/ZTR.csv
# [*********************100%***********************]  1 of 1 completed
# ZTS
# Guardando info en: price_data/ZTS.csv
# [*********************100%***********************]  1 of 1 completed
# ZX
# Guardando info en: price_data/ZX.csv
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ZX: No data found for this date range, symbol may be delisted

# %% [markdown]
# Ahora podemos cargar la función de análisis del episodio anterior, pero la modificamos para que acepte data y no para que la descargue.

# %%
def wick_rejection(df:pd.DataFrame) -> pd.DataFrame:



    # Indicadores teçnicos
    df["EMA200"] = TA.EMA(df, period=200)
    df["EMA50"] = TA.EMA(df, period=50)
    df["ATR"] = TA.ATR(df)

    # Condiciones

    c1 = df["close"] > df["EMA200"]
    c2 = (df["low"] < df["EMA50"]) & (df["close"] > df["EMA50"]) & (df["open"] > df["EMA50"])
    long_entry_condition = (c1) & (c2)

    # Corremos 1 el df para definir la entrada de la posicion
    df["entry"] = df.shift(-1)["open"]

    # Shift to find entry point
    df["entry"] = df.shift(-1)["open"]

    # Creamos columnas en 0 para el TP y SL¿
    df["target"] = 0.0
    df["stop"] = 0.0

    # Find entry and exit
    df.loc[long_entry_condition, "stop"] = df["entry"] - df["ATR"]
    df.loc[long_entry_condition, "target"] = df["entry"] + 1.5*df["ATR"]
    
    # Create new df with only entries
    entries = df.loc[long_entry_condition][['entry', 'target', 'stop']].copy()

    return entries

# %% [markdown]
# Ahora buscamos leer los archivos csv descargados para saber que tickers tenemos, luego analizarlso

# %%
from os import path

# %%
import glob
filepaths = []
results_dict = {}
for file in glob.glob("price_data\\*.csv"):
    filepaths.append(file)

filepaths
# Out:
# ['price_data\\A.csv',
#  'price_data\\AA.csv',
#  'price_data\\AAC.csv',
#  'price_data\\AAN.csv',
#  'price_data\\AAP.csv',
#  'price_data\\AAT.csv',
#  'price_data\\AB.csv',
#  'price_data\\ABB.csv',
#  'price_data\\ABBV.csv',
#  'price_data\\ABC.csv',
#  'price_data\\ABEV.csv',
#  'price_data\\ABG.csv',
#  'price_data\\ABM.csv',
#  'price_data\\ABR.csv',
#  'price_data\\ABT.csv',
#  'price_data\\ACCO.csv',
#  'price_data\\ACE.csv',
#  'price_data\\ACI.csv',
#  'price_data\\ACM.csv',
#  'price_data\\ACN.csv',
#  'price_data\\ACP.csv',
#  'price_data\\ACRE.csv',
#  'price_data\\ACT.csv',
#  'price_data\\ADC.csv',
#  'price_data\\ADM.csv',
#  'price_data\\ADPT.csv',
#  'price_data\\ADT.csv',
#  'price_data\\ADX.csv',
#  'price_data\\AEB.csv',
#  'price_data\\AED.csv',
#  'price_data\\AEE.csv',
#  'price_data\\AEG.csv',
#  'price_data\\AEH.csv',
#  'price_data\\AEL.csv',
#  'price_data\\AEM.csv',
#  'price_data\\AEO.csv',
#  'price_data\\AEP.csv',
#  'price_data\\AER.csv',
#  'price_data\\AES.csv',
#  'price_data\\AET.csv',
#  'price_data\\AFB.csv',
#  'price_data\\AFG.csv',
#  'price_data\\AFGE.csv',
#  'price_data\\AFL.csv',
#  'price_data\\AFM.csv',
#  'price_data\\AFT.csv',
#  'price_data\\AG.csv',
#  'price_data\\AGCO.csv',
#  'price_data\\AGD.csv',
#  'price_data\\AGI.csv',
#  'price_data\\AGM.csv',
#  'price_data\\AGO.csv',
#  'price_data\\AGRO.csv',
#  'price_data\\AGX.csv',
#  'price_data\\AHH.csv',
#  'price_data\\AHL.csv',
#  'price_data\\AHT.csv',
#  'price_data\\AI.csv',
#  'price_data\\AIB.csv',
#  'price_data\\AIF.csv',
#  'price_data\\AIG.csv',
#  'price_data\\AIN.csv',
#  'price_data\\AIR.csv',
#  'price_data\\AIT.csv',
#  'price_data\\AIV.csv',
#  'price_data\\AIZ.csv',
#  'price_data\\AJG.csv',
#  'price_data\\AKR.csv',
#  'price_data\\AL.csv',
#  'price_data\\ALB.csv',
#  'price_data\\ALE.csv',
#  'price_data\\ALEX.csv',
#  'price_data\\ALG.csv',
#  'price_data\\ALK.csv',
#  'price_data\\ALL.csv',
#  'price_data\\ALLE.csv',
#  'price_data\\ALLY.csv',
#  'price_data\\ALR.csv',
#  'price_data\\ALSN.csv',
#  'price_data\\ALU.csv',
#  'price_data\\ALV.csv',
#  'price_data\\ALX.csv',
#  'price_data\\AM.csv',
#  'price_data\\AMC.csv',
#  'price_data\\AME.csv',
#  'price_data\\AMG.csv',
#  'price_data\\AMH.csv',
#  'price_data\\AMID.csv',
#  'price_data\\AMP.csv',
#  'price_data\\AMRC.csv',
#  'price_data\\AMT.csv',
#  'price_data\\AMTD.csv',
#  'price_data\\AMX.csv',
#  'price_data\\AN.csv',
#  'price_data\\ANET.csv',
#  'price_data\\ANF.csv',
#  'price_data\\ANR.csv',
#  'price_data\\AOD.csv',
#  'price_data\\AON.csv',
#  'price_data\\AOS.csv',
#  'price_data\\AP.csv',
#  'price_data\\APA.csv',
#  'price_data\\APAM.csv',
#  'price_data\\APB.csv',
#  'price_data\\APD.csv',
#  'price_data\\APH.csv',
#  'price_data\\APL.csv',
#  'price_data\\APO.csv',
#  'price_data\\AR.csv',
#  'price_data\\ARC.csv',
#  'price_data\\ARCO.csv',
#  'price_data\\ARDC.csv',
#  'price_data\\ARE.csv',
#  'price_data\\ARES.csv',
#  'price_data\\ARI.csv',
#  'price_data\\ARL.csv',
#  'price_data\\ARMK.csv',
#  'price_data\\ARR.csv',
#  'price_data\\ARW.csv',
#  'price_data\\ASA.csv',
#  'price_data\\ASB.csv',
#  'price_data\\ASC.csv',
#  'price_data\\ASG.csv',
#  'price_data\\ASGN.csv',
#  'price_data\\ASH.csv',
#  'price_data\\ASPN.csv',
#  'price_data\\ASR.csv',
#  'price_data\\ASX.csv',
#  'price_data\\ATEN.csv',
#  'price_data\\ATHM.csv',
#  'price_data\\ATI.csv',
#  'price_data\\ATO.csv',
#  'price_data\\ATR.csv',
#  'price_data\\ATTO.csv',
#  'price_data\\ATW.csv',
#  'price_data\\AU.csv',
#  'price_data\\AUY.csv',
#  'price_data\\AVA.csv',
#  'price_data\\AVAL.csv',
#  'price_data\\AVB.csv',
#  'price_data\\AVD.csv',
#  'price_data\\AVIV.csv',
#  'price_data\\AVK.csv',
#  'price_data\\AVT.csv',
#  'price_data\\AVY.csv',
#  'price_data\\AWF.csv',
#  'price_data\\AWH.csv',
#  'price_data\\AWI.csv',
#  'price_data\\AWK.csv',
#  'price_data\\AWP.csv',
#  'price_data\\AWR.csv',
#  'price_data\\AXL.csv',
#  'price_data\\AXP.csv',
#  'price_data\\AXR.csv',
#  'price_data\\AXS.csv',
#  'price_data\\AXTA.csv',
#  'price_data\\AYI.csv',
#  'price_data\\AZN.csv',
#  'price_data\\AZO.csv',
#  'price_data\\AZZ.csv',
#  'price_data\\B.csv',
#  'price_data\\BA.csv',
#  'price_data\\BABA.csv',
#  'price_data\\BAC.csv',
#  'price_data\\BAH.csv',
#  'price_data\\BAK.csv',
#  'price_data\\BALT.csv',
#  'price_data\\BANC.csv',
#  'price_data\\BAP.csv',
#  'price_data\\BAX.csv',
#  'price_data\\BBD.csv',
#  'price_data\\BBDO.csv',
#  'price_data\\BBN.csv',
#  'price_data\\BBVA.csv',
#  'price_data\\BBW.csv',
#  'price_data\\BBY.csv',
#  'price_data\\BC.csv',
#  'price_data\\BCC.csv',
#  'price_data\\BCE.csv',
#  'price_data\\BCH.csv',
#  'price_data\\BCO.csv',
#  'price_data\\BCS.csv',
#  'price_data\\BCX.csv',
#  'price_data\\BDC.csv',
#  'price_data\\BDJ.csv',
#  'price_data\\BDN.csv',
#  'price_data\\BDX.csv',
#  'price_data\\BEN.csv',
#  'price_data\\BEP.csv',
#  'price_data\\BERY.csv',
#  'price_data\\BFAM.csv',
#  'price_data\\BFK.csv',
#  'price_data\\BFS.csv',
#  'price_data\\BFZ.csv',
#  'price_data\\BG.csv',
#  'price_data\\BGB.csv',
#  'price_data\\BGC.csv',
#  'price_data\\BGH.csv',
#  'price_data\\BGR.csv',
#  'price_data\\BGS.csv',
#  'price_data\\BGT.csv',
#  'price_data\\BGX.csv',
#  'price_data\\BGY.csv',
#  'price_data\\BH.csv',
#  'price_data\\BHE.csv',
#  'price_data\\BHI.csv',
#  'price_data\\BHK.csv',
#  'price_data\\BHL.csv',
#  'price_data\\BHLB.csv',
#  'price_data\\BHP.csv',
#  'price_data\\BIG.csv',
#  'price_data\\BIN.csv',
#  'price_data\\BIO.csv',
#  'price_data\\BIP.csv',
#  'price_data\\BIT.csv',
#  'price_data\\BJZ.csv',
#  'price_data\\BK.csv',
#  'price_data\\BKD.csv',
#  'price_data\\BKE.csv',
#  'price_data\\BKH.csv',
#  'price_data\\BKN.csv',
#  'price_data\\BKT.csv',
#  'price_data\\BKU.csv',
#  'price_data\\BLH.csv',
#  'price_data\\BLK.csv',
#  'price_data\\BLW.csv',
#  'price_data\\BLX.csv',
#  'price_data\\BMA.csv',
#  'price_data\\BME.csv',
#  'price_data\\BMI.csv',
#  'price_data\\BMO.csv',
#  'price_data\\BMS.csv',
#  'price_data\\BMY.csv',
#  'price_data\\BNJ.csv',
#  'price_data\\BNK.csv',
#  'price_data\\BNS.csv',
#  'price_data\\BNY.csv',
#  'price_data\\BOE.csv',
#  'price_data\\BOH.csv',
#  'price_data\\BOOT.csv',
#  'price_data\\BP.csv',
#  'price_data\\BPK.csv',
#  'price_data\\BPT.csv',
#  'price_data\\BR.csv',
#  'price_data\\BRC.csv',
#  'price_data\\BRFS.csv',
#  'price_data\\BRO.csv',
#  'price_data\\BRP.csv',
#  'price_data\\BRT.csv',
#  'price_data\\BRX.csv',
#  'price_data\\BSAC.csv',
#  'price_data\\BSBR.csv',
#  'price_data\\BSI.csv',
#  'price_data\\BSL.csv',
#  'price_data\\BSMX.csv',
#  'price_data\\BST.csv',
#  'price_data\\BSX.csv',
#  'price_data\\BTA.csv',
#  'price_data\\BTE.csv',
#  'price_data\\BTF.csv',
#  'price_data\\BTO.csv',
#  'price_data\\BTT.csv',
#  'price_data\\BTU.csv',
#  'price_data\\BTZ.csv',
#  'price_data\\BUD.csv',
#  'price_data\\BUI.csv',
#  'price_data\\BURL.csv',
#  'price_data\\BVN.csv',
#  'price_data\\BWA.csv',
#  'price_data\\BWC.csv',
#  'price_data\\BWG.csv',
#  'price_data\\BX.csv',
#  'price_data\\BXC.csv',
#  'price_data\\BXMT.csv',
#  'price_data\\BXMX.csv',
#  'price_data\\BXP.csv',
#  'price_data\\BYD.csv',
#  'price_data\\BYM.csv',
#  'price_data\\BZH.csv',
#  'price_data\\C.csv',
#  'price_data\\CACI.csv',
#  'price_data\\CAE.csv',
#  'price_data\\CAF.csv',
#  'price_data\\CAG.csv',
#  'price_data\\CAH.csv',
#  'price_data\\CAJ.csv',
#  'price_data\\CALX.csv',
#  'price_data\\CAPL.csv',
#  'price_data\\CAT.csv',
#  'price_data\\CATO.csv',
#  'price_data\\CB.csv',
#  'price_data\\CBA.csv',
#  'price_data\\CBD.csv',
#  'price_data\\CBI.csv',
#  'price_data\\CBL.csv',
#  'price_data\\CBT.csv',
#  'price_data\\CBU.csv',
#  'price_data\\CBZ.csv',
#  'price_data\\CCE.csv',
#  'price_data\\CCI.csv',
#  'price_data\\CCJ.csv',
#  'price_data\\CCK.csv',
#  'price_data\\CCL.csv',
#  'price_data\\CCM.csv',
#  'price_data\\CCO.csv',
#  'price_data\\CCS.csv',
#  'price_data\\CCU.csv',
#  'price_data\\CCV.csv',
#  'price_data\\CCZ.csv',
#  'price_data\\CDE.csv',
#  'price_data\\CE.csv',
#  'price_data\\CEB.csv',
#  'price_data\\CEE.csv',
#  'price_data\\CEM.csv',
#  'price_data\\CEN.csv',
#  'price_data\\CEO.csv',
#  'price_data\\CEQP.csv',
#  'price_data\\CF.csv',
#  'price_data\\CFG.csv',
#  'price_data\\CFI.csv',
#  'price_data\\CFR.csv',
#  'price_data\\CGA.csv',
#  'price_data\\CHD.csv',
#  'price_data\\CHE.csv',
#  'price_data\\CHGG.csv',
#  'price_data\\CHH.csv',
#  'price_data\\CHK.csv',
#  'price_data\\CHKR.csv',
#  'price_data\\CHMI.csv',
#  'price_data\\CHMT.csv',
#  'price_data\\CHN.csv',
#  'price_data\\CHS.csv',
#  'price_data\\CHT.csv',
#  'price_data\\CI.csv',
#  'price_data\\CIA.csv',
#  'price_data\\CIB.csv',
#  'price_data\\CIEN.csv',
#  'price_data\\CIF.csv',
#  'price_data\\CIG.csv',
#  'price_data\\CII.csv',
#  'price_data\\CIM.csv',
#  'price_data\\CIO.csv',
#  'price_data\\CIR.csv',
#  'price_data\\CIVI.csv',
#  'price_data\\CL.csv',
#  'price_data\\CLB.csv',
#  'price_data\\CLC.csv',
#  'price_data\\CLDT.csv',
#  'price_data\\CLF.csv',
#  'price_data\\CLH.csv',
#  'price_data\\CLS.csv',
#  'price_data\\CLW.csv',
#  'price_data\\CLX.csv',
#  'price_data\\CM.csv',
#  'price_data\\CMA.csv',
#  'price_data\\CMC.csv',
#  'price_data\\CMCM.csv',
#  'price_data\\CMG.csv',
#  'price_data\\CMI.csv',
#  'price_data\\CMP.csv',
#  'price_data\\CMRE.csv',
#  'price_data\\CMS.csv',
#  'price_data\\CMU.csv',
#  'price_data\\CNA.csv',
#  'price_data\\CNC.csv',
#  'price_data\\CNHI.csv',
#  'price_data\\CNI.csv',
#  'price_data\\CNK.csv',
#  'price_data\\CNO.csv',
#  'price_data\\CNP.csv',
#  'price_data\\CNQ.csv',
#  'price_data\\CNS.csv',
#  'price_data\\CNX.csv',
#  'price_data\\CO.csv',
#  'price_data\\CODI.csv',
#  'price_data\\COF.csv',
#  'price_data\\COL.csv',
#  'price_data\\COO.csv',
#  'price_data\\COP.csv',
#  'price_data\\CORR.csv',
#  'price_data\\COTY.csv',
#  'price_data\\COUP.csv',
#  'price_data\\COV.csv',
#  'price_data\\CP.csv',
#  'price_data\\CPA.csv',
#  'price_data\\CPAC.csv',
#  'price_data\\CPB.csv',
#  'price_data\\CPE.csv',
#  'price_data\\CPF.csv',
#  'price_data\\CPG.csv',
#  'price_data\\CPK.csv',
#  'price_data\\CPS.csv',
#  'price_data\\CPT.csv',
#  'price_data\\CRC.csv',
#  'price_data\\CRH.csv',
#  'price_data\\CRI.csv',
#  'price_data\\CRK.csv',
#  'price_data\\CRL.csv',
#  'price_data\\CRM.csv',
#  'price_data\\CRS.csv',
#  'price_data\\CRT.csv',
#  'price_data\\CS.csv',
#  'price_data\\CSC.csv',
#  'price_data\\CSH.csv',
#  'price_data\\CSL.csv',
#  'price_data\\CSTM.csv',
#  'price_data\\CSV.csv',
#  'price_data\\CSX.csv',
#  'price_data\\CTLT.csv',
#  'price_data\\CTR.csv',
#  'price_data\\CTS.csv',
#  'price_data\\CTV.csv',
#  'price_data\\CTX.csv',
#  'price_data\\CUBE.csv',
#  'price_data\\CUBI.csv',
#  'price_data\\CUBS.csv',
#  'price_data\\CUDA.csv',
#  'price_data\\CUK.csv',
#  'price_data\\CUZ.csv',
#  'price_data\\CVE.csv',
#  'price_data\\CVEO.csv',
#  'price_data\\CVG.csv',
#  'price_data\\CVI.csv',
#  'price_data\\CVRR.csv',
#  'price_data\\CVS.csv',
#  'price_data\\CVT.csv',
#  'price_data\\CVX.csv',
#  'price_data\\CW.csv',
#  'price_data\\CWT.csv',
#  'price_data\\CX.csv',
#  'price_data\\CXE.csv',
#  'price_data\\CXH.csv',
#  'price_data\\CXW.csv',
#  'price_data\\CYD.csv',
#  'price_data\\CYH.csv',
#  'price_data\\CYN.csv',
#  'price_data\\CYT.csv',
#  'price_data\\D.csv',
#  'price_data\\DAC.csv',
#  'price_data\\DAL.csv',
#  'price_data\\DAN.csv',
#  'price_data\\DAR.csv',
#  'price_data\\DB.csv',
#  'price_data\\DBD.csv',
#  'price_data\\DBL.csv',
#  'price_data\\DCI.csv',
#  'price_data\\DCM.csv',
#  'price_data\\DCO.csv',
#  'price_data\\DCT.csv',
#  'price_data\\DD.csv',
#  'price_data\\DDD.csv',
#  'price_data\\DDF.csv',
#  'price_data\\DDR.csv',
#  'price_data\\DDS.csv',
#  'price_data\\DDT.csv',
#  'price_data\\DE.csv',
#  'price_data\\DECK.csv',
#  'price_data\\DEI.csv',
#  'price_data\\DEO.csv',
#  'price_data\\DEX.csv',
#  'price_data\\DFP.csv',
#  'price_data\\DFS.csv',
#  'price_data\\DG.csv',
#  'price_data\\DGX.csv',
#  'price_data\\DHF.csv',
#  'price_data\\DHI.csv',
#  'price_data\\DHR.csv',
#  'price_data\\DHT.csv',
#  'price_data\\DHX.csv',
#  'price_data\\DIAX.csv',
#  'price_data\\DIN.csv',
#  'price_data\\DIS.csv',
#  'price_data\\DK.csv',
#  'price_data\\DKL.csv',
#  'price_data\\DKS.csv',
#  'price_data\\DLB.csv',
#  'price_data\\DLNG.csv',
#  'price_data\\DLR.csv',
#  'price_data\\DLX.csv',
#  'price_data\\DM.csv',
#  'price_data\\DMB.csv',
#  'price_data\\DMO.csv',
#  'price_data\\DNB.csv',
#  'price_data\\DNOW.csv',
#  'price_data\\DNP.csv',
#  'price_data\\DO.csv',
#  'price_data\\DOC.csv',
#  'price_data\\DOOR.csv',
#  'price_data\\DOV.csv',
#  'price_data\\DOW.csv',
#  'price_data\\DPG.csv',
#  'price_data\\DPZ.csv',
#  'price_data\\DQ.csv',
#  'price_data\\DRC.csv',
#  'price_data\\DRD.csv',
#  'price_data\\DRH.csv',
#  'price_data\\DRI.csv',
#  'price_data\\DRL.csv',
#  'price_data\\DRQ.csv',
#  'price_data\\DSL.csv',
#  'price_data\\DSM.csv',
#  'price_data\\DSU.csv',
#  'price_data\\DSX.csv',
#  'price_data\\DTE.csv',
#  'price_data\\DTF.csv',
#  'price_data\\DTT.csv',
#  'price_data\\DUK.csv',
#  'price_data\\DUKH.csv',
#  'price_data\\DV.csv',
#  'price_data\\DVA.csv',
#  'price_data\\DVN.csv',
#  'price_data\\DX.csv',
#  'price_data\\DY.csv',
#  'price_data\\DYN.csv',
#  'price_data\\E.csv',
#  'price_data\\EARN.csv',
#  'price_data\\EAT.csv',
#  'price_data\\EBF.csv',
#  'price_data\\EBR.csv',
#  'price_data\\EBS.csv',
#  'price_data\\EC.csv',
#  'price_data\\ECC.csv',
#  'price_data\\ECL.csv',
#  'price_data\\ED.csv',
#  'price_data\\EDD.csv',
#  'price_data\\EDF.csv',
#  'price_data\\EDI.csv',
#  'price_data\\EDN.csv',
#  'price_data\\EDR.csv',
#  'price_data\\EDU.csv',
#  'price_data\\EE.csv',
#  'price_data\\EEA.csv',
#  'price_data\\EEP.csv',
#  'price_data\\EEQ.csv',
#  'price_data\\EFC.csv',
#  'price_data\\EFR.csv',
#  'price_data\\EFT.csv',
#  'price_data\\EFX.csv',
#  'price_data\\EGF.csv',
#  'price_data\\EGL.csv',
#  'price_data\\EGN.csv',
#  'price_data\\EGO.csv',
#  'price_data\\EGP.csv',
#  'price_data\\EGY.csv',
#  'price_data\\EHI.csv',
#  'price_data\\EIG.csv',
#  'price_data\\EIX.csv',
#  'price_data\\EL.csv',
#  'price_data\\ELA.csv',
#  'price_data\\ELP.csv',
#  'price_data\\ELS.csv',
#  'price_data\\ELU.csv',
#  'price_data\\EMC.csv',
#  'price_data\\EMD.csv',
#  'price_data\\EME.csv',
#  'price_data\\EMF.csv',
#  'price_data\\EMN.csv',
#  'price_data\\EMO.csv',
#  'price_data\\EMR.csv',
#  'price_data\\ENB.csv',
#  'price_data\\ENJ.csv',
#  'price_data\\ENLC.csv',
#  'price_data\\ENLK.csv',
#  'price_data\\ENR.csv',
#  'price_data\\ENS.csv',
#  'price_data\\ENV.csv',
#  'price_data\\ENVA.csv',
#  'price_data\\ENZ.csv',
#  'price_data\\EOD.csv',
#  'price_data\\EOG.csv',
#  'price_data\\EOI.csv',
#  'price_data\\EOS.csv',
#  'price_data\\EOT.csv',
#  'price_data\\EPAM.csv',
#  'price_data\\EPD.csv',
#  'price_data\\EPR.csv',
#  'price_data\\EQC.csv',
#  'price_data\\EQR.csv',
#  'price_data\\EQS.csv',
#  'price_data\\EQT.csv',
#  'price_data\\ERF.csv',
#  'price_data\\ERJ.csv',
#  'price_data\\ESE.csv',
#  'price_data\\ESI.csv',
#  'price_data\\ESNT.csv',
#  'price_data\\ESRT.csv',
#  'price_data\\ESS.csv',
#  'price_data\\ETB.csv',
#  'price_data\\ETG.csv',
#  'price_data\\ETJ.csv',
#  'price_data\\ETN.csv',
#  'price_data\\ETO.csv',
#  'price_data\\ETP.csv',
#  'price_data\\ETR.csv',
#  'price_data\\ETV.csv',
#  'price_data\\ETW.csv',
#  'price_data\\ETX.csv',
#  'price_data\\ETY.csv',
#  'price_data\\EVC.csv',
#  'price_data\\EVER.csv',
#  'price_data\\EVF.csv',
#  'price_data\\EVG.csv',
#  'price_data\\EVGN.csv',
#  'price_data\\EVHC.csv',
#  'price_data\\EVN.csv',
#  'price_data\\EVR.csv',
#  'price_data\\EVT.csv',
#  'price_data\\EVTC.csv',
#  'price_data\\EW.csv',
#  'price_data\\EXC.csv',
#  'price_data\\EXD.csv',
#  'price_data\\EXG.csv',
#  'price_data\\EXK.csv',
#  'price_data\\EXP.csv',
#  'price_data\\EXPR.csv',
#  'price_data\\EXR.csv',
#  'price_data\\EZT.csv',
#  'price_data\\F.csv',
#  'price_data\\FAF.csv',
#  'price_data\\FAM.csv',
#  'price_data\\FBP.csv',
#  'price_data\\FBR.csv',
#  'price_data\\FC.csv',
#  'price_data\\FCB.csv',
#  'price_data\\FCF.csv',
#  'price_data\\FCN.csv',
#  'price_data\\FCT.csv',
#  'price_data\\FCX.csv',
#  'price_data\\FDP.csv',
#  'price_data\\FDS.csv',
#  'price_data\\FDX.csv',
#  'price_data\\FE.csv',
#  'price_data\\FEI.csv',
#  'price_data\\FENG.csv',
#  'price_data\\FEO.csv',
#  'price_data\\FET.csv',
#  'price_data\\FF.csv',
#  'price_data\\FFA.csv',
#  'price_data\\FFC.csv',
#  'price_data\\FGB.csv',
#  'price_data\\FHN.csv',
#  'price_data\\FICO.csv',
#  'price_data\\FIF.csv',
#  'price_data\\FIG.csv',
#  'price_data\\FIS.csv',
#  'price_data\\FIX.csv',
#  'price_data\\FL.csv',
#  'price_data\\FLC.csv',
#  'price_data\\FLO.csv',
#  'price_data\\FLR.csv',
#  'price_data\\FLS.csv',
#  'price_data\\FLT.csv',
#  'price_data\\FMC.csv',
#  'price_data\\FMN.csv',
#  'price_data\\FMO.csv',
#  'price_data\\FMS.csv',
#  'price_data\\FMX.csv',
#  'price_data\\FMY.csv',
#  'price_data\\FN.csv',
#  'price_data\\FNB.csv',
#  'price_data\\FNF.csv',
#  'price_data\\FNV.csv',
#  'price_data\\FOF.csv',
#  'price_data\\FOR.csv',
#  'price_data\\FPF.csv',
#  'price_data\\FPL.csv',
#  'price_data\\FPT.csv',
#  'price_data\\FR.csv',
#  'price_data\\FRA.csv',
#  'price_data\\FRC.csv',
#  'price_data\\FRM.csv',
#  'price_data\\FRO.csv',
#  'price_data\\FRT.csv',
#  'price_data\\FSD.csv',
#  'price_data\\FSM.csv',
#  'price_data\\FSS.csv',
#  'price_data\\FT.csv',
#  'price_data\\FTI.csv',
#  'price_data\\FTK.csv',
#  'price_data\\FUL.csv',
#  'price_data\\FUN.csv',
#  'price_data\\G.csv',
#  'price_data\\GAB.csv',
#  'price_data\\GAM.csv',
#  'price_data\\GAS.csv',
#  'price_data\\GB.csv',
#  'price_data\\GBAB.csv',
#  'price_data\\GBX.csv',
#  'price_data\\GCI.csv',
#  'price_data\\GCO.csv',
#  'price_data\\GCV.csv',
#  'price_data\\GD.csv',
#  'price_data\\GDL.csv',
#  'price_data\\GDO.csv',
#  'price_data\\GDOT.csv',
#  'price_data\\GDV.csv',
#  'price_data\\GE.csv',
#  'price_data\\GEB.csv',
#  'price_data\\GEF.csv',
#  'price_data\\GEL.csv',
#  'price_data\\GEO.csv',
#  'price_data\\GER.csv',
#  'price_data\\GES.csv',
#  'price_data\\GF.csv',
#  'price_data\\GFA.csv',
#  'price_data\\GFF.csv',
#  'price_data\\GFI.csv',
#  'price_data\\GGB.csv',
#  'price_data\\GGE.csv',
#  'price_data\\GGG.csv',
#  'price_data\\GGT.csv',
#  'price_data\\GGZ.csv',
#  'price_data\\GHC.csv',
#  'price_data\\GHI.csv',
#  'price_data\\GHL.csv',
#  'price_data\\GHM.csv',
#  'price_data\\GHY.csv',
#  'price_data\\GIB.csv',
#  'price_data\\GIL.csv',
#  'price_data\\GIM.csv',
#  'price_data\\GIS.csv',
#  'price_data\\GJH.csv',
#  'price_data\\GJO.csv',
#  'price_data\\GJP.csv',
#  'price_data\\GJR.csv',
#  'price_data\\GJS.csv',
#  'price_data\\GJT.csv',
#  'price_data\\GLF.csv',
#  'price_data\\GLOB.csv',
#  'price_data\\GLOP.csv',
#  'price_data\\GLP.csv',
#  'price_data\\GLT.csv',
#  'price_data\\GLW.csv',
#  'price_data\\GM.csv',
#  'price_data\\GME.csv',
#  'price_data\\GMED.csv',
#  'price_data\\GNE.csv',
#  'price_data\\GNRC.csv',
#  'price_data\\GNT.csv',
#  'price_data\\GNW.csv',
#  'price_data\\GOF.csv',
#  'price_data\\GOL.csv',
#  'price_data\\GPC.csv',
#  'price_data\\GPI.csv',
#  'price_data\\GPK.csv',
#  'price_data\\GPN.csv',
#  'price_data\\GPRK.csv',
#  'price_data\\GPS.csv',
#  'price_data\\GPT.csv',
#  'price_data\\GRX.csv',
#  'price_data\\GS.csv',
#  'price_data\\GSK.csv',
#  'price_data\\GSL.csv',
#  'price_data\\GTN.csv',
#  'price_data\\GTY.csv',
#  'price_data\\GUT.csv',
#  'price_data\\GVA.csv',
#  'price_data\\GWRE.csv',
#  'price_data\\GWW.csv',
#  'price_data\\GYC.csv',
#  'price_data\\H.csv',
#  'price_data\\HAE.csv',
#  'price_data\\HAL.csv',
#  'price_data\\HAR.csv',
#  'price_data\\HASI.csv',
#  'price_data\\HBI.csv',
#  'price_data\\HBM.csv',
#  'price_data\\HCA.csv',
#  'price_data\\HCC.csv',
#  'price_data\\HCI.csv',
#  'price_data\\HCP.csv',
#  'price_data\\HD.csv',
#  'price_data\\HDB.csv',
#  'price_data\\HE.csv',
#  'price_data\\HEI.csv',
#  'price_data\\HEP.csv',
#  'price_data\\HEQ.csv',
#  'price_data\\HES.csv',
#  'price_data\\HHC.csv',
#  'price_data\\HHS.csv',
#  'price_data\\HI.csv',
#  'price_data\\HIE.csv',
#  'price_data\\HIG.csv',
#  'price_data\\HII.csv',
#  'price_data\\HIO.csv',
#  'price_data\\HIVE.csv',
#  'price_data\\HIW.csv',
#  'price_data\\HIX.csv',
#  'price_data\\HL.csv',
#  'price_data\\HLF.csv',
#  'price_data\\HLT.csv',
#  'price_data\\HLX.csv',
#  'price_data\\HMC.csv',
#  'price_data\\HMN.csv',
#  'price_data\\HMY.csv',
#  'price_data\\HNI.csv',
#  'price_data\\HOG.csv',
#  'price_data\\HON.csv',
#  'price_data\\HOV.csv',
#  'price_data\\HP.csv',
#  'price_data\\HPF.csv',
#  'price_data\\HPI.csv',
#  'price_data\\HPP.csv',
#  'price_data\\HPQ.csv',
#  'price_data\\HPS.csv',
#  'price_data\\HQH.csv',
#  'price_data\\HQL.csv',
#  'price_data\\HR.csv',
#  'price_data\\HRB.csv',
#  'price_data\\HRL.csv',
#  'price_data\\HRTG.csv',
#  'price_data\\HSBC.csv',
#  'price_data\\HSC.csv',
#  'price_data\\HSEB.csv',
#  'price_data\\HST.csv',
#  'price_data\\HSY.csv',
#  'price_data\\HT.csv',
#  'price_data\\HTD.csv',
#  'price_data\\HTGC.csv',
#  'price_data\\HTH.csv',
#  'price_data\\HTY.csv',
#  'price_data\\HTZ.csv',
#  'price_data\\HUBS.csv',
#  'price_data\\HUM.csv',
#  'price_data\\HUN.csv',
#  'price_data\\HVT.csv',
#  'price_data\\HXL.csv',
#  'price_data\\HY.csv',
#  'price_data\\HYB.csv',
#  'price_data\\HYI.csv',
#  'price_data\\HYT.csv',
#  'price_data\\HZO.csv',
#  'price_data\\IAE.csv',
#  'price_data\\IAG.csv',
#  'price_data\\IBA.csv',
#  'price_data\\IBM.csv',
#  'price_data\\IBN.csv',
#  'price_data\\IBP.csv',
#  'price_data\\ICD.csv',
#  'price_data\\ICE.csv',
#  'price_data\\ICL.csv',
#  'price_data\\IDA.csv',
#  'price_data\\IDE.csv',
#  'price_data\\IDT.csv',
#  'price_data\\IEX.csv',
#  'price_data\\IFF.csv',
#  'price_data\\IFN.csv',
#  'price_data\\IGA.csv',
#  'price_data\\IGD.csv',
#  'price_data\\IGI.csv',
#  'price_data\\IGR.csv',
#  'price_data\\IGT.csv',
#  'price_data\\IHD.csv',
#  'price_data\\IHG.csv',
#  'price_data\\IHS.csv',
#  'price_data\\IIF.csv',
#  'price_data\\IIM.csv',
#  'price_data\\IM.csv',
#  'price_data\\IMAX.csv',
#  'price_data\\IMPV.csv',
#  'price_data\\IND.csv',
#  'price_data\\INFY.csv',
#  'price_data\\ING.csv',
#  'price_data\\INGR.csv',
#  'price_data\\INN.csv',
#  'price_data\\INT.csv',
#  'price_data\\IP.csv',
#  'price_data\\IPG.csv',
#  'price_data\\IPI.csv',
#  'price_data\\IQI.csv',
#  'price_data\\IR.csv',
#  'price_data\\IRL.csv',
#  'price_data\\IRM.csv',
#  'price_data\\IRS.csv',
#  'price_data\\ISD.csv',
#  'price_data\\ISP.csv',
#  'price_data\\IT.csv',
#  'price_data\\ITC.csv',
#  'price_data\\ITT.csv',
#  'price_data\\ITUB.csv',
#  'price_data\\ITW.csv',
#  'price_data\\IVH.csv',
#  'price_data\\IVR.csv',
#  'price_data\\IVZ.csv',
#  'price_data\\IX.csv',
#  'price_data\\JBK.csv',
#  'price_data\\JBL.csv',
#  'price_data\\JBR.csv',
#  'price_data\\JBT.csv',
#  'price_data\\JCE.csv',
#  'price_data\\JCI.csv',
#  'price_data\\JEQ.csv',
#  'price_data\\JFR.csv',
#  'price_data\\JGH.csv',
#  'price_data\\JHI.csv',
#  'price_data\\JHS.csv',
#  'price_data\\JHX.csv',
#  'price_data\\JKS.csv',
#  'price_data\\JLL.csv',
#  'price_data\\JLS.csv',
#  'price_data\\JMM.csv',
#  'price_data\\JNJ.csv',
#  'price_data\\JNPR.csv',
#  'price_data\\JOE.csv',
#  'price_data\\JOF.csv',
#  'price_data\\JPC.csv',
#  'price_data\\JPI.csv',
#  'price_data\\JPM.csv',
#  'price_data\\JPS.csv',
#  'price_data\\JQC.csv',
#  'price_data\\JRI.csv',
#  'price_data\\JRO.csv',
#  'price_data\\JSD.csv',
#  'price_data\\JWN.csv',
#  'price_data\\K.csv',
#  'price_data\\KAI.csv',
#  'price_data\\KAMN.csv',
#  'price_data\\KAR.csv',
#  'price_data\\KB.csv',
#  'price_data\\KBH.csv',
#  'price_data\\KBR.csv',
#  'price_data\\KEN.V.csv',
#  'price_data\\KEP.csv',
#  'price_data\\KEX.csv',
#  'price_data\\KEY.csv',
#  'price_data\\KEYS.csv',
#  'price_data\\KF.csv',
#  'price_data\\KFS.csv',
#  'price_data\\KFY.csv',
#  'price_data\\KGC.csv',
#  'price_data\\KIM.csv',
#  'price_data\\KIO.csv',
#  'price_data\\KKR.csv',
#  'price_data\\KMB.csv',
#  'price_data\\KMF.csv',
#  'price_data\\KMG.csv',
#  'price_data\\KMI.csv',
#  'price_data\\KMM.csv',
#  'price_data\\KMPA.csv',
#  'price_data\\KMPR.csv',
#  'price_data\\KMT.csv',
#  'price_data\\KMX.csv',
#  'price_data\\KN.csv',
#  'price_data\\KNOP.csv',
#  'price_data\\KNX.csv',
#  'price_data\\KO.csv',
#  'price_data\\KODK.csv',
#  'price_data\\KOF.csv',
#  'price_data\\KOP.csv',
#  'price_data\\KOS.csv',
#  'price_data\\KR.csv',
#  'price_data\\KRC.csv',
#  'price_data\\KRG.csv',
#  'price_data\\KRO.csv',
#  'price_data\\KS.csv',
#  'price_data\\KSM.csv',
#  'price_data\\KSS.csv',
#  'price_data\\KST.csv',
#  'price_data\\KT.csv',
#  'price_data\\KTF.csv',
#  'price_data\\KTH.csv',
#  'price_data\\KTN.csv',
#  'price_data\\KW.csv',
#  'price_data\\KWR.csv',
#  'price_data\\KYN.csv',
#  'price_data\\L.csv',
#  'price_data\\LAD.csv',
#  'price_data\\LADR.csv',
#  'price_data\\LAZ.csv',
#  'price_data\\LC.csv',
#  'price_data\\LCI.csv',
#  'price_data\\LDF.csv',
#  'price_data\\LDOS.csv',
#  'price_data\\LDP.csv',
#  'price_data\\LEA.csv',
#  'price_data\\LEE.csv',
#  'price_data\\LEG.csv',
#  'price_data\\LEJU.csv',
#  'price_data\\LEN.csv',
#  'price_data\\LEO.csv',
#  'price_data\\LEU.csv',
#  'price_data\\LGI.csv',
#  'price_data\\LH.csv',
#  'price_data\\LHO.csv',
#  'price_data\\LII.csv',
#  'price_data\\LITB.csv',
#  'price_data\\LL.csv',
#  'price_data\\LLY.csv',
#  'price_data\\LMT.csv',
#  'price_data\\LNC.csv',
#  'price_data\\LND.csv',
#  'price_data\\LNN.csv',
#  'price_data\\LNT.csv',
#  'price_data\\LOW.csv',
#  'price_data\\LPG.csv',
#  'price_data\\LPL.csv',
#  'price_data\\LPX.csv',
#  'price_data\\LRN.csv',
#  'price_data\\LTC.csv',
#  'price_data\\LUV.csv',
#  ...]

# %% [markdown]
# Corremos en un bucle que busque todos los tickers y pueda aplicar la función de busqueda

# %%
for path in filepaths[0:15]:
    df = pd.read_csv(path, index_col='datetime')
    symbol = path.split('\\')[-1].split('.')[0]
    print(symbol)
    print(path)
    entry_df = wick_rejection(df)
    results_dict[symbol] = entry_df
# Out:
# A
# price_data\A.csv
# AA
# price_data\AA.csv
# AAC
# price_data\AAC.csv
# AAN
# price_data\AAN.csv
# AAP
# price_data\AAP.csv
# AAT
# price_data\AAT.csv
# AB
# price_data\AB.csv
# ABB
# price_data\ABB.csv
# ABBV
# price_data\ABBV.csv
# ABC
# price_data\ABC.csv
# ABEV
# price_data\ABEV.csv
# ABG
# price_data\ABG.csv
# ABM
# price_data\ABM.csv
# ABR
# price_data\ABR.csv
# ABT
# price_data\ABT.csv

# %%
results_dict
# Out:
# {'A':                  entry      target        stop
#  datetime
#  2018-06-07   62.966390   64.748226   61.778500
#  2018-06-15   63.091650   64.760957   61.978779
#  2018-07-19   61.650379   63.012039   60.742606
#  2018-08-16   63.244029   65.168833   61.960826
#  2018-11-07   65.807308   68.568921   63.966232
#  2018-11-20   65.487903   68.233959   63.657199
#  2019-01-08   66.173826   69.498265   63.957534
#  2019-06-20   71.112166   72.965393   69.876681
#  2019-06-24   71.160773   72.966081   69.957234
#  2019-06-25   70.626038   72.441762   69.415555
#  2019-06-27   71.228828   73.033091   70.025986
#  2019-10-18   73.121164   75.451186   71.567816
#  2019-10-25   73.912119   75.970116   72.540121
#  2020-02-19   83.080866   85.525900   81.450843
#  2020-09-21   96.188815   99.959798   93.674827
#  2020-09-23   94.940241   98.668037   92.455043
#  2020-10-29  100.232899  103.431352   98.100597
#  2020-10-30  101.956452  105.157015   99.822743
#  2021-01-28  119.575053  123.274473  117.108772
#  2021-02-23  120.610898  125.252085  117.516773
#  2021-02-25  121.271855  126.048336  118.087534
#  2021-02-26  121.390237  126.167776  118.205212
#  2021-03-11  118.943673  124.311004  115.365453
#  2021-03-19  120.522109  125.405343  117.266620
#  2021-03-23  120.472786  125.119257  117.375139
#  2021-05-11  128.777549  131.877090  126.711189
#  2021-05-13  128.905994  132.092341  126.781762
#  2021-09-27  162.434995  167.713672  158.915877
#  2021-11-10  158.764245  163.487010  155.615735
#  2021-11-12  159.725073  164.753489  156.372796
#  2022-01-03  154.222407  159.405481  150.767024
#  2022-11-03  135.227688  141.423694  131.097016
#  2023-01-06  149.446539  155.205130  145.607478
#  2023-01-31  153.060655  158.199427  149.634807
#  2023-02-07  153.390108  158.543851  149.954280
#  2023-02-10  153.020718  157.996895  149.703266
#  2023-02-14  151.972426  156.803129  148.751957
#  2023-02-15  148.567970  153.427553  145.328249,
#  'AA':                 entry     target       stop
#  datetime
#  2021-02-05  21.089044  22.790956  19.954436
#  2021-06-24  36.532595  39.036839  34.863098
